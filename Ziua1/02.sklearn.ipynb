# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# Pentru instalare (in terminal):
#
# # pip install scikit-learn
#
# Pentru folosire in cod:
#
# # import sklearn

# %%
from sklearn.datasets import make_regression

# %%
regression_data = make_regression(n_samples=10, n_features=1)
type(regression_data)
# Out:
# tuple

# %%
x, y = regression_data
type(x), type(y)
# Out:
# (numpy.ndarray, numpy.ndarray)

# %%
x.shape, y.shape
# Out:
# ((10, 1), (10,))

# %%
plt.scatter(x, y)
plt.plot(x, y)

# %%
x, y = make_regression(n_samples=10, n_features=1, noise=1)
plt.scatter(x, y)

# %%
x, y = make_regression(n_samples=10, n_features=1, noise=5)
plt.scatter(x, y)

# %%
x, y = make_regression(n_samples=10, n_features=1, noise=20)
plt.scatter(x, y)

# %%
x, y = make_regression(n_samples=100, n_features=1, noise=20)
plt.scatter(x, y)

# %%
x, y = make_regression(n_samples=1000, n_features=1, noise=20)
plt.scatter(x, y)

# %%
from sklearn.linear_model import LinearRegression

# %%
model = LinearRegression()
model
# Out:
# LinearRegression()

# %%
model.fit(x,y)
# Out:
# LinearRegression()

# %%
model.coef_, model.intercept_
# Out:
# (array([66.89390037]), np.float64(-1.2756245299436955))

# %%
x, y = make_regression(n_samples=1000, n_features=1, noise=20)
plt.scatter(x, y)

plt.plot(x, x * model.coef_ + model.intercept_, c="black")
