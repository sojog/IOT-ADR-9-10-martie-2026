# %%
import requests

# %%
URL = "http://localhost:11434/api/generate"

# %%
MODEL = "qwen2.5-coder:14b"

# %%
PROMPT = "Explica-mi protocolul MQTT"

# %%
payload = {
    "model" : MODEL,
    "prompt" : PROMPT,
    "stream" : False
}

# %%
response = requests.post(URL, json=payload)
response.content
# Out:
# b'{"model":"qwen2.5-coder:14b","created_at":"2026-03-10T08:10:06.421Z","response":"MQTT (Message Queuing Telemetry Transport) este un protocol de comunicare lightweight, orientat spre eficien\xc8\x9b\xc4\x83 \xc8\x99i fiabilitate, conceput pentru conexiuni \xc3\xaentre sisteme IoT (Internet of Things). Iat\xc4\x83 principalele caracteristici \xc8\x99i concepte ale protocolului MQTT:\\n\\n1. **Conexiune \xc8\x99i Autentificare**:\\n   - MQTT folose\xc8\x99te TCP/IP pentru stabilirea conexiunilor.\\n   - Clientii (produc\xc4\x83tori sau consumatori) se conecteaz\xc4\x83 la un broker MQTT.\\n   - Autentificarea \xc8\x99i autorizarea pot fi implementate prin utilizarea de utilizatori \xc8\x99i parole sau prin metode de autentificare mai avansate.\\n\\n2. **QoS (Quality of Service)**:\\n   - MQTT ofer\xc4\x83 trei niveluri de serviciu (QoS):\\n     - QoS 0: \\"At most once\\" - mesajul poate fi pierdut, dar nu va fi trimis de mai multe ori.\\n     - QoS 1: \\"At least once\\" - mesajul va
# ...

# %%
print(response.text)
# Out:
# {"model":"qwen2.5-coder:14b","created_at":"2026-03-10T08:10:06.421Z","response":"MQTT (Message Queuing Telemetry Transport) este un protocol de comunicare lightweight, orientat spre eficiență și fiabilitate, conceput pentru conexiuni între sisteme IoT (Internet of Things). Iată principalele caracteristici și concepte ale protocolului MQTT:\n\n1. **Conexiune și Autentificare**:\n   - MQTT folosește TCP/IP pentru stabilirea conexiunilor.\n   - Clientii (producători sau consumatori) se conectează la un broker MQTT.\n   - Autentificarea și autorizarea pot fi implementate prin utilizarea de utilizatori și parole sau prin metode de autentificare mai avansate.\n\n2. **QoS (Quality of Service)**:\n   - MQTT oferă trei niveluri de serviciu (QoS):\n     - QoS 0: \"At most once\" - mesajul poate fi pierdut, dar nu va fi trimis de mai multe ori.\n     - QoS 1: \"At least once\" - mesajul va fi transmis cel puțin o dată, garantând livrarea.\n     - QoS 2: \"Exactly once\" - mesajul va fi transmis
# ...

# %%
response.json()["response"]
# Out:
# 'MQTT (Message Queuing Telemetry Transport) este un protocol de comunicare lightweight, orientat spre eficiență și fiabilitate, conceput pentru conexiuni între sisteme IoT (Internet of Things). Iată principalele caracteristici și concepte ale protocolului MQTT:\n\n1. **Conexiune și Autentificare**:\n   - MQTT folosește TCP/IP pentru stabilirea conexiunilor.\n   - Clientii (producători sau consumatori) se conectează la un broker MQTT.\n   - Autentificarea și autorizarea pot fi implementate prin utilizarea de utilizatori și parole sau prin metode de autentificare mai avansate.\n\n2. **QoS (Quality of Service)**:\n   - MQTT oferă trei niveluri de serviciu (QoS):\n     - QoS 0: "At most once" - mesajul poate fi pierdut, dar nu va fi trimis de mai multe ori.\n     - QoS 1: "At least once" - mesajul va fi transmis cel puțin o dată, garantând livrarea.\n     - QoS 2: "Exactly once" - mesajul va fi transmis exact o dată, asigurând livrarea unică.\n\n3. **Teme și Abonamente**:\n   - MQTT folo
# ...
