# %%
import pandas as pd
import sqlite3

# %%
df = pd.DataFrame({"temp": [39, 18], "humidity": [40, 40]})
df
# Out:
#    temp  humidity
# 0    39        40
# 1    18        40

# %%
df.to_csv("demo.csv")

# %%
df.to_json("demo.json")

# %%
conexiunea = sqlite3.connect("demo.sqlite3")

df.to_sql("Data", conexiunea)
# Out:
# 2
