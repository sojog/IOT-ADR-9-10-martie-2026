# %%
import pandas as pd
import numpy as np

# %%
df= pd.read_csv("Titanic-Dataset.csv", index_col=0)
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df["Embarked"]
# Out:
# PassengerId
# 1      S
# 2      C
# 3      S
# 4      S
# 5      S
#       ..
# 887    S
# 888    S
# 889    S
# 890    C
# 891    Q
# Name: Embarked, Length: 891, dtype: object

# %%
df["Embarked"].unique()
# Out:
# array(['S', 'C', 'Q', nan], dtype=object)

# %%
df["Embarked"].isna().sum()
# Out:
# np.int64(2)

# %%
df[df["Embarked"].isna()]
# Out:
#              Survived  Pclass                                       Name  \
# PassengerId
# 62                  1       1                        Icard, Miss. Amelie
# 830                 1       1  Stone, Mrs. George Nelson (Martha Evelyn)
#
#                 Sex   Age  SibSp  Parch  Ticket  Fare Cabin Embarked
# PassengerId
# 62           female  38.0      0      0  113572  80.0   B28      NaN
# 830          female  62.0      0      0  113572  80.0   B28      NaN

# %%
df["Embarked"].count()
# Out:
# np.int64(889)

# %%
df[~df["Embarked"].isna()]["Embarked"]
# Out:
# PassengerId
# 1      S
# 2      C
# 3      S
# 4      S
# 5      S
#       ..
# 887    S
# 888    S
# 889    S
# 890    C
# 891    Q
# Name: Embarked, Length: 889, dtype: object

# %%
all_embarked_df = df[~df["Embarked"].isna()]["Embarked"]
all_embarked_df
# Out:
# PassengerId
# 1      S
# 2      C
# 3      S
# 4      S
# 5      S
#       ..
# 887    S
# 888    S
# 889    S
# 890    C
# 891    Q
# Name: Embarked, Length: 889, dtype: object

# %%
all_embarked_df.unique()
# Out:
# array(['S', 'C', 'Q'], dtype=object)

# %%
all_embarked_df[all_embarked_df == "S"].count()
# Out:
# np.int64(644)

# %%
all_embarked_df[all_embarked_df == "C"].count()
# Out:
# np.int64(168)

# %%
all_embarked_df[all_embarked_df == "Q"].count()
# Out:
# np.int64(77)

# %%
df.count()
# Out:
# Survived    891
# Pclass      891
# Name        891
# Sex         891
# Age         714
# SibSp       891
# Parch       891
# Ticket      891
# Fare        891
# Cabin       204
# Embarked    889
# dtype: int64

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C

# %%
df["Cabin_first_letter"] = df["Cabin"].astype(str).str[0]
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name     Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    male  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...  female  38.0
# 3                                       Heikkinen, Miss. Laina  female  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)  female  35.0
# 5                                     Allen, Mr. William Henry    male  35.0
# ...                                                        ...     ...   ...
# ...

# %%
df.Cabin.unique()
# Out:
# array([nan, 'C85', 'C123', 'E46', 'G6', 'C103', 'D56', 'A6',
#        'C23 C25 C27', 'B78', 'D33', 'B30', 'C52', 'B28', 'C83', 'F33',
#        'F G73', 'E31', 'A5', 'D10 D12', 'D26', 'C110', 'B58 B60', 'E101',
#        'F E69', 'D47', 'B86', 'F2', 'C2', 'E33', 'B19', 'A7', 'C49', 'F4',
#        'A32', 'B4', 'B80', 'A31', 'D36', 'D15', 'C93', 'C78', 'D35',
#        'C87', 'B77', 'E67', 'B94', 'C125', 'C99', 'C118', 'D7', 'A19',
#        'B49', 'D', 'C22 C26', 'C106', 'C65', 'E36', 'C54',
#        'B57 B59 B63 B66', 'C7', 'E34', 'C32', 'B18', 'C124', 'C91', 'E40',
#        'T', 'C128', 'D37', 'B35', 'E50', 'C82', 'B96 B98', 'E10', 'E44',
#        'A34', 'C104', 'C111', 'C92', 'E38', 'D21', 'E12', 'E63', 'A14',
#        'B37', 'C30', 'D20', 'B79', 'E25', 'D46', 'B73', 'C95', 'B38',
#        'B39', 'B22', 'C86', 'C70', 'A16', 'C101', 'C68', 'A10', 'E68',
#        'B41', 'A20', 'D19', 'D50', 'D9', 'A23', 'B50', 'A26', 'D48',
# ...

# %%
df.Cabin_first_letter.unique()
# Out:
# array(['n', 'C', 'E', 'G', 'D', 'A', 'B', 'F', 'T'], dtype=object)

# %%
df.dtypes
# Out:
# Survived                int64
# Pclass                  int64
# Name                   object
# Sex                    object
# Age                   float64
# SibSp                   int64
# Parch                   int64
# Ticket                 object
# Fare                  float64
# Cabin                  object
# Embarked               object
# Cabin_first_letter     object
# dtype: object

# %%
df["Name"].nunique()
# Out:
# 891

# %%
df["Sex"].unique()
# Out:
# array(['male', 'female'], dtype=object)

# %%
df["Sex"] = df["Sex"].map({"male":0, "female":1})
df
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
# 3                   1       3
# 4                   1       1
# 5                   0       3
# ...               ...     ...
# 887                 0       2
# 888                 1       1
# 889                 0       3
# 890                 1       1
# 891                 0       3
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
# 3                                       Heikkinen, Miss. Laina    1  26.0
# 4                 Futrelle, Mrs. Jacques Heath (Lily May Peel)    1  35.0
# 5                                     Allen, Mr. William Henry    0  35.0
# ...                                                        ...  ...   ...
# ...

# %%
df.dtypes
# Out:
# Survived                int64
# Pclass                  int64
# Name                   object
# Sex                     int64
# Age                   float64
# SibSp                   int64
# Parch                   int64
# Ticket                 object
# Fare                  float64
# Cabin                  object
# Embarked               object
# Cabin_first_letter     object
# dtype: object

# %%
df["Ticket"].nunique()
# Out:
# 681

# %%
df["Ticket"].isna().sum()
# Out:
# np.int64(0)

# %%
df.head(2)
# Out:
#              Survived  Pclass  \
# PassengerId
# 1                   0       3
# 2                   1       1
#
#                                                           Name  Sex   Age  \
# PassengerId
# 1                                      Braund, Mr. Owen Harris    0  22.0
# 2            Cumings, Mrs. John Bradley (Florence Briggs Th...    1  38.0
#
#              SibSp  Parch     Ticket     Fare Cabin Embarked  \
# PassengerId
# 1                1      0  A/5 21171   7.2500   NaN        S
# 2                1      0   PC 17599  71.2833   C85        C
#
#             Cabin_first_letter
# PassengerId
# 1                            n
# 2                            C

# %%
df = df.drop(["Name", "Ticket", "Cabin"], axis=1)
df
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare Embarked  \
# PassengerId
# 1                   0       3    0  22.0      1      0   7.2500        S
# 2                   1       1    1  38.0      1      0  71.2833        C
# 3                   1       3    1  26.0      0      0   7.9250        S
# 4                   1       1    1  35.0      1      0  53.1000        S
# 5                   0       3    0  35.0      0      0   8.0500        S
# ...               ...     ...  ...   ...    ...    ...      ...      ...
# 887                 0       2    0  27.0      0      0  13.0000        S
# 888                 1       1    1  19.0      0      0  30.0000        S
# 889                 0       3    1   NaN      1      2  23.4500        S
# 890                 1       1    0  26.0      0      0  30.0000        C
# 891                 0       3    0  32.0      0      0   7.7500        Q
#
#             Cabin_first_letter
# PassengerId
# 1                            n
# ...

# %%
df["Embarked"] = df["Embarked"].map({"S":0, "C":1, "Q":2})
df
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# PassengerId
# 1                   0       3    0  22.0      1      0   7.2500       0.0
# 2                   1       1    1  38.0      1      0  71.2833       1.0
# 3                   1       3    1  26.0      0      0   7.9250       0.0
# 4                   1       1    1  35.0      1      0  53.1000       0.0
# 5                   0       3    0  35.0      0      0   8.0500       0.0
# ...               ...     ...  ...   ...    ...    ...      ...       ...
# 887                 0       2    0  27.0      0      0  13.0000       0.0
# 888                 1       1    1  19.0      0      0  30.0000       0.0
# 889                 0       3    1   NaN      1      2  23.4500       0.0
# 890                 1       1    0  26.0      0      0  30.0000       1.0
# 891                 0       3    0  32.0      0      0   7.7500       2.0
#
#             Cabin_first_letter
# PassengerId
# ...

# %%
value = df["Cabin_first_letter"].unique()
value.sort()
value
# Out:
# array(['A', 'B', 'C', 'D', 'E', 'F', 'G', 'T', 'n'], dtype=object)

# %%
mapped_values = { val:index for index, val in enumerate(value) }
mapped_values
# Out:
# {'A': 0, 'B': 1, 'C': 2, 'D': 3, 'E': 4, 'F': 5, 'G': 6, 'T': 7, 'n': 8}

# %%
df["Cabin_first_letter"] = df["Cabin_first_letter"].map(mapped_values)
df
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# PassengerId
# 1                   0       3    0  22.0      1      0   7.2500       0.0
# 2                   1       1    1  38.0      1      0  71.2833       1.0
# 3                   1       3    1  26.0      0      0   7.9250       0.0
# 4                   1       1    1  35.0      1      0  53.1000       0.0
# 5                   0       3    0  35.0      0      0   8.0500       0.0
# ...               ...     ...  ...   ...    ...    ...      ...       ...
# 887                 0       2    0  27.0      0      0  13.0000       0.0
# 888                 1       1    1  19.0      0      0  30.0000       0.0
# 889                 0       3    1   NaN      1      2  23.4500       0.0
# 890                 1       1    0  26.0      0      0  30.0000       1.0
# 891                 0       3    0  32.0      0      0   7.7500       2.0
#
#              Cabin_first_letter
# PassengerId
# ...

# %%
df.corr()
# Out:
#                     Survived    Pclass       Sex       Age     SibSp  \
# Survived            1.000000 -0.338481  0.543351 -0.077221 -0.035322
# Pclass             -0.338481  1.000000 -0.131900 -0.369226  0.083081
# Sex                 0.543351 -0.131900  1.000000 -0.093254  0.114631
# Age                -0.077221 -0.369226 -0.093254  1.000000 -0.308247
# SibSp              -0.035322  0.083081  0.114631 -0.308247  1.000000
# Parch               0.081629  0.018443  0.245489 -0.189119  0.414838
# Fare                0.257307 -0.549500  0.182333  0.096067  0.159651
# Embarked            0.108669  0.043835  0.118593  0.012186 -0.060606
# Cabin_first_letter -0.301116  0.746616 -0.123076 -0.267270  0.041540
#
#                        Parch      Fare  Embarked  Cabin_first_letter
# Survived            0.081629  0.257307  0.108669           -0.301116
# Pclass              0.018443 -0.549500  0.043835            0.746616
# Sex                 0.245489  0.182333  0.118593           -0.123076
# ...

# %% [markdown]
# # pip install seaborn

# %%
import seaborn as sns

# %%
sns.heatmap(df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
import matplotlib.pyplot as plt

# %%
plt.scatter(df["Age"], df["Sex"])
plt.xlabel("Age")
plt.ylabel("Gender 0-female, 1-male")
# Out:
# Text(0, 0.5, 'Gender 0-female, 1-male')

# %%
plt.scatter(df["Age"], df["Sex"], c=df["Survived"].map({0:"red", 1:"green"}))
plt.xlabel("Age")
plt.ylabel("Gender 0-female, 1-male")
# Out:
# Text(0, 0.5, 'Gender 0-female, 1-male')

# %%
plt.rcParams["figure.figsize"] #  [6.4, 4.8]
# Out:
# [6.4, 4.8]

# %%
plt.rcParams["figure.figsize"] = [6.4 * 2, 4.8]

# %%
plt.scatter(df["Age"], df["Sex"], c=df["Survived"].map({0:"red", 1:"green"}))
plt.xlabel("Age")
plt.ylabel("Gender 0-female, 1-male")
# Out:
# Text(0, 0.5, 'Gender 0-female, 1-male')

# %%
over_14_df = df[df["Age"] > 14]
over_14_df
# Out:
#              Survived  Pclass  Sex   Age  SibSp  Parch     Fare  Embarked  \
# PassengerId
# 1                   0       3    0  22.0      1      0   7.2500       0.0
# 2                   1       1    1  38.0      1      0  71.2833       1.0
# 3                   1       3    1  26.0      0      0   7.9250       0.0
# 4                   1       1    1  35.0      1      0  53.1000       0.0
# 5                   0       3    0  35.0      0      0   8.0500       0.0
# ...               ...     ...  ...   ...    ...    ...      ...       ...
# 886                 0       3    1  39.0      0      5  29.1250       2.0
# 887                 0       2    0  27.0      0      0  13.0000       0.0
# 888                 1       1    1  19.0      0      0  30.0000       0.0
# 890                 1       1    0  26.0      0      0  30.0000       1.0
# 891                 0       3    0  32.0      0      0   7.7500       2.0
#
#              Cabin_first_letter
# PassengerId
# ...

# %%
plt.rcParams["figure.figsize"] = [6.4, 4.8]

sns.heatmap(over_14_df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
plt.rcParams["figure.figsize"] = [6.4, 4.8]

sns.heatmap(df.corr(), cmap="coolwarm")
# Out:
# <Axes: >

# %%
df.describe()
# Out:
#          Survived      Pclass         Sex         Age       SibSp       Parch  \
# count  891.000000  891.000000  891.000000  714.000000  891.000000  891.000000
# mean     0.383838    2.308642    0.352413   29.699118    0.523008    0.381594
# std      0.486592    0.836071    0.477990   14.526497    1.102743    0.806057
# min      0.000000    1.000000    0.000000    0.420000    0.000000    0.000000
# 25%      0.000000    2.000000    0.000000   20.125000    0.000000    0.000000
# 50%      0.000000    3.000000    0.000000   28.000000    0.000000    0.000000
# 75%      1.000000    3.000000    1.000000   38.000000    1.000000    0.000000
# max      1.000000    3.000000    1.000000   80.000000    8.000000    6.000000
#
#              Fare    Embarked  Cabin_first_letter
# count  891.000000  889.000000          891.000000
# mean    32.204208    0.362205            6.716049
# std     49.693429    0.636157            2.460739
# min      0.000000    0.000000            0.000000
# ...
