# %%
import time
import datetime

# %%
time.time()
# Out:
# 1773145612.5793102

# %%
time.time()
# Out:
# 1773145620.740544

# %%
datetime.datetime.now()
# Out:
# datetime.datetime(2026, 3, 10, 14, 27, 11, 193597)

# %%
time.strftime("%Y-%m-%d %H:%M:%S")
# Out:
# '2026-03-10 14:29:12'
